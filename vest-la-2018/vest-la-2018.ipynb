# %%
##VEST Louisiana 2018 Shapefile validation

"""
Louisiana
---------
Election results from LA Secretary of State (https://voterportal.sos.la.gov/static/)
Precinct shapefile from LA House of Representatives (http://house.louisiana.gov/H_Redistricting2011/default_LouisianaPrecinctShapefiles)

Early votes were reported at the parish level. These were distributed by candidate to precincts based on their share of the precinct-level reported vote.

Election results from the following parishes include "alpha" precincts in which voters within the same geographic boundaries are assigned to separate precincts by the first letter of their surname: Ascension, Assumption, Bossier, Caddo, East Baton Rouge, Lafayette, Lafourche, Rapides, St. Charles, St. Landry, Terrebonne

The following precincts were modified to reflect alterations enacted prior to the 2018 election:

Avoyelles: Merge 2-5B/6-1A
Plaquemines: Merge 2-1/2-2, 4-1/4-2, 5-1/5-2
St. Charles: Merge 2-6/2-7, 3-1/3-6, 3-3/3-4, 6-2/6-3, 6-4/6-5
Vermilion: Split 49B-1/49B-2
West Baton Rouge: Split 2-A/2-B; 11-A/11-B

G18SOSRARD - Kyle Ardoin (Republican Party)
G18SOSREDM - "Rick" Edmongs (Republican Party)
G18SOSRSTO - Julie Stokes (Republican Party)
G18SOSRKEN - Thomas J. Kennedy III (Republican Party)
G18SOSRCRO - A.G. Crowe (Republican Party)
G18SOSRCLO - Heather Cloud (Republican Party)
G18SOSDCOL - "Gwen" Collins-Greenup (Democratic Party)
G18SOSDFRE - Renee Fontenot Free (Democratic Party)
G18SOSNMOR - Matthew Paul "Matt" Moreau (No Party)

R18SOSRARD - Kyle Ardoin (Republican Party)
R18SOSDCOL - "Gwen" Collins-Greenup (Democratic Party)


Raw files: 
    - 2018 Louisiana Precinct File (from LA House of Representatives, as a .shp)
    - 2018 Louisiana SoS Primary Election results - precinct (from LA SoS, as a .csv)
    - 2018 Louisiana SoS Priary Election results - parish (from LA SoS, as a .csv)
    - 2018 Louisiana SoS General Election results (from LA SoS, as a .csv)
    - 2018 Louisiana SoS General Election results (from LA SoS, as a .csv)
    
    
Steps:
1. Load in all four files (one final, five raw)
2. Merge listed alterations above in raw file, rename accordingly
3. Validate the geographies with each other (the merged raw and the final)
MERGE???
4. Election results alpha precincts???
5. Interpolate precinct results from county results (mail in and early)
6. 
"""
# Out:
# '\nLouisiana\n---------\nElection results from LA Secretary of State (https://voterportal.sos.la.gov/static/)\nPrecinct shapefile from LA House of Representatives (http://house.louisiana.gov/H_Redistricting2011/default_LouisianaPrecinctShapefiles)\n\nEarly votes were reported at the parish level. These were distributed by candidate to precincts based on their share of the precinct-level reported vote.\n\nElection results from the following parishes include "alpha" precincts in which voters within the same geographic boundaries are assigned to separate precincts by the first letter of their surname: Ascension, Assumption, Bossier, Caddo, East Baton Rouge, Lafayette, Lafourche, Rapides, St. Charles, St. Landry, Terrebonne\n\nThe following precincts were modified to reflect alterations enacted prior to the 2018 election:\n\nAvoyelles: Merge 2-5B/6-1A\nPlaquemines: Merge 2-1/2-2, 4-1/4-2, 5-1/5-2\nSt. Charles: Merge 2-6/2-7, 3-1/3-6, 3-3/3-4, 6-2/6-3, 6-4/6-5\nVermilion: Split 49B-1/49B-2\nWest Baton Rouge: Split 2-A/2-B; 11-A/11-B\n\nG18SOSRARD - Kyle Ardoin (Republican Party)\nG18SOSREDM - "Rick" Edmongs (Republican Party)\nG18SOSRSTO - Julie Stokes (Republican Party)\nG18SOSRKEN - Thomas J. Kennedy III (Republican Party)\nG18SOSRCRO - A.G. Crowe (Republican Party)\nG18SOSRCLO - Heather Cloud (Republican Party)\nG18SOSDCOL - "Gwen" Collins-Greenup (Democratic Party)\nG18SOSDFRE - Renee Fontenot Free (Democratic Party)\nG18SOSNMOR - Matthew Paul "Matt" Moreau (No Party)\n\nR18SOSRARD - Kyle Ardoin (Republican Party)\nR18SOSDCOL - "Gwen" Collins-Greenup (Democratic Party)\n\n\nRaw files: \n    - 2018 Louisiana Precinct File (from LA House of Representatives, as a .shp)\n    - 2018 Louisiana SoS Primary Election results - precinct (from LA SoS, as a .csv)\n    - 2018 Louisiana SoS Priary Election results - parish (from LA SoS, as a .csv)\n    - 2018 Louisiana SoS General Election results (from LA SoS, as a .csv)\n    - 2018 Louisiana SoS General Election results (from LA SoS, as a .csv)\n    \n    \nSteps:\n1. Load in all four files (one final, five raw)\n2. Merge listed alterations above in raw file, rename accordingly\n3. Validate the geographies with each other (the merged raw and the final)\nMERGE???\n4. Election results alpha precincts???\n5. Interpolate precinct results from county results (mail in and early)\n6. \n'

# %%
"""Run all of the necessary imports"""
import matplotlib.pyplot as plt # for plotting maps
import pandas as pd # standard python data library
import geopandas as gp # the geo-version of pandas
import numpy as np 
from statistics import mean, median
import timeit 
import requests

# %%
""""Start a timer"""
start = timeit.default_timer()

# %%
"""Import the four raw csv datasets"""

SoSGen_Parish = pd.read_csv('./raw-data/election_results_la/SoSGeneral2018_LAParsih.csv')
SoSGen_Precinct = pd.read_csv('./raw-data/election_results_la/SoSGeneral2018_LAPrecincts.csv')
SoSPrim_Parish = pd.read_csv('./raw-data/election_results_la/SoSPrimary2018_LAParish.csv')
SoSPrim_Precinct = pd.read_csv('./raw-data/election_results_la/SoSPrimary2018_LAPrecincts.csv')

# %%
"""Import the two shapefiles (one raw, one final)"""

precincts = gp.read_file('./raw-data/2018 LA Precincts for the Web/2018 LA Precincts for the Web.shp')
final = gp.read_file('./final_vest_la_2018/la_2018.shp')

# %%
"""In order to merge/dissolve the boundaries listed above in the documentation,
we need to identify which those are -- this only done by county so 
we will retrieve the county FIPS for those counties
"""
#Function to retrieve the county fips codes for all counies
def counties(state_fips):
    """Inputs: state fips code
    Process: Retrieves a list of counties in the given state from the Census API.  
    Outputs: A list of county fips codes in the state. """
    #uses the fips input into the census api
    resp = requests.get(
        "https://api.census.gov/data/2010/dec/sf1"
        "?get=NAME&for=county:*&in=state:{}".format(state_fips)  #uses the fips input to locate the state
    )
    #retrieves the data as a json 
    test = resp.json()
    header, *rows = resp.json()
    #county column is "county"
    county_column_index = header.index("county")
    county_fips = set(row[county_column_index] for row in rows) #sequence of counties 
    county_names_index = header.index("NAME")
    county_names = set(row[county_names_index] for row in rows) #names of the counties
    county_fips = np.array(list(county_fips)) #make the sets into numpy arrays
    county_names = np.array(list(county_names))
    df = pd.DataFrame({'COUNTYFP10': county_fips, 'COUNTYNAMES': county_names}) #make pd dataframe of arrays
    return df  #returns the fips codes of all counties

#run the function for LA (FIPS code 22)
LA_counties = counties(22)

#check the number of parishes and values for the columns
LA_counties.nunique()
# Out:
# COUNTYFP10     64
# COUNTYNAMES    64
# dtype: int64

# %%
#check the number of values for counties in the precincts file
precincts['COUNTYFP10'].nunique()
# Out:
# 64

# %%
##merge the county names to the precincts shapefile by the fips
precincts_countynames = precincts.merge(LA_counties, on=['COUNTYFP10'], how='inner')
#make sure it's still a geodataframe
type(precincts_countynames)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
##Check to make sure no precincts were dropped in the merge
precincts_cases = precincts.shape[0]
prec_names = precincts_countynames.shape[0]
print("number of differing precincts: ", abs(precincts_cases-prec_names))
# Out:
# number of differing precincts:  0

# %%
final['GEOID10']=final['STATEFP10']+final['COUNTYFP10']+final['VTDST10']
final=final.merge(LA_counties,on=['COUNTYFP10'], how='inner')
joined = pd.merge(final, precincts_countynames, on=['GEOID10'], indicator=True, how='outer')
differing_precincts = joined[joined['_merge'] != 'both']
print('number of differing precincts: ', differing_precincts.shape[0])
differing_precincts_GEOIDs = [differing_precincts['GEOID10']]
print(differing_precincts_GEOIDs)
joined_inner = pd.merge(final, precincts_countynames, on=['GEOID10'], how='inner')
final_rows = final.shape[0]
precinct_rows = precincts_countynames.shape[0]
print("Number of different rows: ", abs(final_rows-precinct_rows))
print("raw file rows: ", precinct_rows)
print("vest-la rows: ", final_rows)
print("outer merge test rows: ", joined.shape[0])
differing_precincts.head(14)
# Out:
# number of differing precincts:  14
# [82      2211349B-2
# 2985       221212A
# 2986      2212111B
# 3327       2208751
# 3710     220092-5B
# 3711      220752-2
# 3712      220755-2
# 3713      220754-2
# 3714      220896-3
# 3715      220896-5
# 3716      220893-6
# 3717      220892-7
# 3718      220893-4
# 3719       2208758
# Name: GEOID10, dtype: object]
# Number of different rows:  6
# raw file rows:  3716
# vest-la rows:  3710
# outer merge test rows:  3720
#      STATEFP10_x COUNTYFP10_x VTDST10_x        NAME10_x  G18SOSRARD  \
# 82            22          113     49B-2  Precinct 49B-2        54.0
# 2985          22          121        2A     Precinct 2A       310.0
# 2986          22          121       11B    Precinct 11B        20.0
# 3327          22          087        51     Precinct 51        13.0
# 3710         NaN          NaN       NaN             NaN         NaN
# 3711         NaN          NaN       NaN             NaN         NaN
# 3712         NaN          NaN       NaN             NaN         NaN
# 3713         NaN          NaN       NaN             NaN         NaN
# 3714         NaN          NaN       NaN             NaN         NaN
# 3715         NaN          NaN       NaN             NaN         NaN
# 3716         NaN          NaN       NaN             NaN         NaN
# 3717         NaN          NaN       NaN             NaN         NaN
# 3718         NaN          NaN       NaN             NaN         NaN
# 3719         NaN          NaN       NaN             NaN         NaN
#
#       G18SOSREDM  G18SOSRSTO  G18SOSRKEN  G18SOSRCRO  G18SOSRCLO  ...   VTD  \
# 82          21.0        19.0        21.0        12.0        12.0  ...   NaN
# 2985       119.0        72.0        38.0        14.0        23.0  ...   NaN
# 2986        11.0         4.0         1.0         0.0         0.0  ...   NaN
# 3327        17.0        26.0        21.0        69.0         4.0  ...   NaN
# 3710         NaN         NaN         NaN         NaN         NaN  ...  2-5B
# 3711         NaN         NaN         NaN         NaN         NaN  ...   2-2
# 3712         NaN         NaN         NaN         NaN         NaN  ...   5-2
# 3713         NaN         NaN         NaN         NaN         NaN  ...   4-2
# 3714         NaN         NaN         NaN         NaN         NaN  ...   6-3
# 3715         NaN         NaN         NaN         NaN         NaN  ...   6-5
# 3716         NaN         NaN         NaN         NaN         NaN  ...   3-6
# 3717         NaN         NaN         NaN         NaN         NaN  ...   2-7
# 3718         NaN         NaN         NaN         NaN         NaN  ...   3-4
# 3719         NaN         NaN         NaN         NaN         NaN  ...    58
#
#       TRACT  BGROUP  BLOCK  TOT_POP SHAPE_AREA SHAPE_LEN  \
# 82      NaN     NaN    NaN      NaN        NaN       NaN
# 2985    NaN     NaN    NaN      NaN        NaN       NaN
# 2986    NaN     NaN    NaN      NaN        NaN       NaN
# 3327    NaN     NaN    NaN      NaN        NaN       NaN
# 3710   None    None   None     75.0    0.00016  0.072198
# 3711   None    None   None   1393.0    0.00048  0.097914
# 3712   None    None   None   1614.0    0.00067  0.205141
# 3713   None    None   None   1833.0    0.00052  0.134172
# 3714   None    None   None   1889.0    0.00249  0.228105
# 3715   None    None   None    352.0    0.00236  0.283257
# 3716   None    None   None     77.0    0.00001  0.014716
# 3717   None    None   None    323.0    0.00033  0.078675
# 3718   None    None   None    760.0    0.00008  0.038696
# 3719   None    None   None    658.0    0.50081  3.075982
#
#                                              geometry_y  \
# 82                                                 None
# 2985                                               None
# 2986                                               None
# 3327                                               None
# 3710  POLYGON ((-91.89467 31.11142, -91.89445 31.111...
# 3711  POLYGON ((-89.99418 29.89268, -89.99420 29.892...
# 3712  POLYGON ((-90.01772 29.87860, -90.01763 29.878...
# 3713  POLYGON ((-89.99002 29.83905, -89.99057 29.838...
# 3714  POLYGON ((-90.39931 30.07477, -90.39698 30.073...
# 3715  POLYGON ((-90.37115 30.05746, -90.37097 30.057...
# 3716  POLYGON ((-90.37627 29.97766, -90.37680 29.977...
# 3717  POLYGON ((-90.36737 29.95401, -90.36724 29.953...
# 3718  POLYGON ((-90.37943 29.96926, -90.37925 29.968...
# 3719  POLYGON ((-88.87923 29.64741, -88.94719 29.647...
#
#                       COUNTYNAMES_y      _merge
# 82                              NaN   left_only
# 2985                            NaN   left_only
# 2986                            NaN   left_only
# 3327                            NaN   left_only
# 3710  Plaquemines Parish, Louisiana  right_only
# 3711     Richland Parish, Louisiana  right_only
# 3712     Richland Parish, Louisiana  right_only
# 3713     Richland Parish, Louisiana  right_only
# 3714    Morehouse Parish, Louisiana  right_only
# 3715    Morehouse Parish, Louisiana  right_only
# 3716    Morehouse Parish, Louisiana  right_only
# 3717    Morehouse Parish, Louisiana  right_only
# 3718    Morehouse Parish, Louisiana  right_only
# 3719     Franklin Parish, Louisiana  right_only
#
# [14 rows x 51 columns]

# %%
"""Avoyelles: Merge 2-5B/6-1A
St. Charles: Merge 2-6/2-7, 3-1/3-6, 3-3/3-4, 6-2/6-3, 6-4/6-5
Vermilion: Split 49B-1/49B-2
West Baton Rouge: Split 2-A/2-B; 11-A/11-B"""
# Out:
# 'Avoyelles: Merge 2-5B/6-1A\nSt. Charles: Merge 2-6/2-7, 3-1/3-6, 3-3/3-4, 6-2/6-3, 6-4/6-5\nVermilion: Split 49B-1/49B-2\nWest Baton Rouge: Split 2-A/2-B; 11-A/11-B'

# %%
def dissolve_precinctsLA(countyname, precinct1, precinct2):
    data = precincts_countynames[(precincts_countynames.COUNTYNAMES == countyname) & ((precincts_countynames.VTD == precinct1) |  (precincts_countynames.VTD == precinct2))]
    dissolved_precinct = data.dissolve(by='COUNTYFP10', aggfunc='sum')
    return dissolved_precinct

# %%
PlaqueminesD1 = dissolve_precinctsLA('Plaquemines Parish, Louisiana', '2-1', '2-2')
PlaqueminesD2 = dissolve_precinctsLA('Plaquemines Parish, Louisiana', '4-1', '4-2')
PlaqueminesD3 = dissolve_precinctsLA('Plaquemines Parish, Louisiana', '5-1', '5-2')

# %%
"""acadia_raw = precincts_countynames[(precincts_countynames.COUNTYNAMES == 'Acadia Parish, Louisiana')]
acadia_elections = SoSGen_Precinct[(SoSGen_Precinct.Parish == 'Acadia')]
acadia_final = final[(final.COUNTYFP10 == '065')]
acadia_raw_cases = acadia_raw.shape[0]
acadia_elec_cases = acadia_elections.shape[0]
acadia_final_cases = acadia_final.shape[0]
print("raw: ", acadia_raw_cases, "SoS: ", acadia_elec_cases, "VEST: ", acadia_final_cases)
#acadia_elections['Precinct'] = acadia_elections['Precinct'].str[:2]
##combine ward and precinct
acadia_elections['ward_prec']=acadia_elections['Ward'].str.cat(acadia_elections['Precinct'],sep="-")
acadia_elections['ward_prec']"""
# Out:
# 'acadia_raw = precincts_countynames[(precincts_countynames.COUNTYNAMES == \'Acadia Parish, Louisiana\')]\nacadia_elections = SoSGen_Precinct[(SoSGen_Precinct.Parish == \'Acadia\')]\nacadia_final = final[(final.COUNTYFP10 == \'065\')]\nacadia_raw_cases = acadia_raw.shape[0]\nacadia_elec_cases = acadia_elections.shape[0]\nacadia_final_cases = acadia_final.shape[0]\nprint("raw: ", acadia_raw_cases, "SoS: ", acadia_elec_cases, "VEST: ", acadia_final_cases)\n#acadia_elections[\'Precinct\'] = acadia_elections[\'Precinct\'].str[:2]\n##combine ward and precinct\nacadia_elections[\'ward_prec\']=acadia_elections[\'Ward\'].str.cat(acadia_elections[\'Precinct\'],sep="-")\nacadia_elections[\'ward_prec\']'

# %%
final.head(50)
# Out:
#    STATEFP10 COUNTYFP10 VTDST10          NAME10  G18SOSRARD  G18SOSREDM  \
# 0         22        111      24     Precinct 24          89          49
# 1         22        111      22     Precinct 22         149          78
# 2         22        111      18     Precinct 18         124          71
# 3         22        111      23     Precinct 23         100          60
# 4         22        111      20     Precinct 20          93          58
# 5         22        111       4      Precinct 4         119          90
# 6         22        111       8      Precinct 8          18          11
# 7         22        111       5      Precinct 5          51          52
# 8         22        111       6      Precinct 6         113          64
# 9         22        111      12     Precinct 12          29          26
# 10        22        111      15     Precinct 15          35          25
# 11        22        111      14     Precinct 14          14           6
# 12        22        111       2      Precinct 2          54          29
# 13        22        111       3      Precinct 3          46          26
# 14        22        111       1      Precinct 1          10           4
# 15        22        111      4A     Precinct 4A           1           1
# 16        22        111     17A    Precinct 17A          35           7
# 17        22        111      17     Precinct 17          95          37
# 18        22        111      19     Precinct 19          83          49
# 19        22        111      16     Precinct 16          72          39
# 20        22        111       9      Precinct 9          12           6
# 21        22        111      10     Precinct 10          48          18
# 22        22        111       7      Precinct 7         115          63
# 23        22        111      11     Precinct 11         118          54
# 24        22        111      13     Precinct 13           4           2
# 25        22        111      27     Precinct 27         109          64
# 26        22        111      28     Precinct 28         106          54
# 27        22        111      29     Precinct 29         156          74
# 28        22        111      26     Precinct 26          51          29
# 29        22        113      23     Precinct 23         127          55
# 30        22        113      16     Precinct 16          24          18
# 31        22        113      14     Precinct 14         244          89
# 32        22        113   20B-1  Precinct 20B-1          77          17
# 33        22        113   20A-2  Precinct 20A-2          24           9
# 34        22        113      8B     Precinct 8B          67          35
# 35        22        113      12     Precinct 12          53           9
# 36        22        113      7B     Precinct 7B         171          59
# 37        22        113     10A    Precinct 10A         126          34
# 38        22        113       1      Precinct 1         211         111
# 39        22        113       6      Precinct 6         152          36
# 40        22        113      5A     Precinct 5A          78          48
# 41        22        113       9      Precinct 9         140          49
# 42        22        113       2      Precinct 2         128          53
# 43        22        113      11     Precinct 11          86          49
# 44        22        113    7A-1   Precinct 7A-1          29          17
# 45        22        113     57B    Precinct 57B          34          19
# 46        22        113     57A    Precinct 57A         186          79
# 47        22        113      53     Precinct 53         269         125
# 48        22        113     42A    Precinct 42A         108          44
# 49        22        113     45A    Precinct 45A          93          36
#
#     G18SOSRSTO  G18SOSRKEN  G18SOSRCRO  G18SOSRCLO  G18SOSDCOL  G18SOSDFRE  \
# 0           25          45          11          12          60          53
# 1           30          79          21          30          11          15
# 2           22          77          11          23           7          15
# 3           42          93          17          17           7          15
# 4           20          67           4          21           8           9
# 5           29          99          16          31          31          80
# 6            6          15           6           5           1          10
# 7           17          47          17          13          23          24
# 8           36          66          14          29          22          20
# 9            4          22           8          11         123          74
# 10           6          14           1           5          20          11
# 11           3          19           6           4         103          55
# 12          13          36          11           7          47          31
# 13          11          40          20          20         116         144
# 14           7          21           1           7          26          30
# 15           1           0           1           0           0           5
# 16           5          31           4           4           1           2
# 17          11          70          16          27           8          21
# 18          24          71           3          33          19          14
# 19          18          51          11          21          37          14
# 20           4           5           3           3          16          11
# 21           8          34           3           8          20          16
# 22          34          59          11          15          22          18
# 23          40          57          20          31          79          63
# 24           2           3           0           0          14          10
# 25          37          51          14          15           7           5
# 26          37          83          13          21          28          17
# 27          41         131          41          48           9          24
# 28          23          45          16          24          65          58
# 29          73          78          17          27          20          40
# 30          15          26           8           7           4           5
# 31          66         128          18          41          29          51
# 32          23          37           7          14           2           9
# 33           6          12           2           7           9           6
# 34          25          18           9          13           4           5
# 35          19          26           3          13          88          60
# 36          44          56          10          27          15          21
# 37          21          50          22          23          25          32
# 38          49         104          31          42          18          43
# 39          43          54          19          18          15          41
# 40          10          35          22          14           5          10
# 41          35          48          13          25          39          46
# 42          36          78          12          36          39          80
# 43          27          52          10          19          25          21
# 44           9           4           3           5           0           0
# 45           7          13           2           8           0           7
# 46          47          90          16          23          27          38
# 47          89         124          26          44          54          75
# 48          35          74          19          28          21          41
# 49          22          42           4          16          17          21
#
#     G18SOSNMOR  R18SOSRARD  R18SOSDCOL  \
# 0            3          80          13
# 1            5         110          13
# 2            1          51           0
# 3            3          98          17
# 4            5          84           3
# 5            6         101          25
# 6            1           9           3
# 7            3          62          15
# 8            1          70          10
# 9            1          31         106
# 10           0          31          11
# 11           1           5          81
# 12           1          32          28
# 13           4          35         137
# 14           1           5          14
# 15           0           3           0
# 16           0          34           0
# 17           0          64           8
# 18           1          43           8
# 19           5          44          24
# 20           1           8          13
# 21           1          36           3
# 22           0          80          11
# 23           3          70          34
# 24           0           3          10
# 25           3         144          11
# 26           6         106          10
# 27          11         121           8
# 28           7          52          28
# 29           7         333          47
# 30           0          60           5
# 31          16         435          79
# 32           2          50           5
# 33           4          28           9
# 34           0          41           0
# 35           7          33          33
# 36           9         111          11
# 37           3          69          11
# 38           9         161           9
# 39           6          49           7
# 40           4          73           8
# 41           6         112          18
# 42          10          87          22
# 43           2          79           4
# 44           0          17           0
# 45           2          23           0
# 46           7          90          14
# 47          13         124          36
# 48           2         176          34
# 49           5          46          16
#
#                                              geometry     GEOID10  \
# 0   POLYGON ((-92.34486 33.01065, -92.34482 33.010...     2211124
# 1   POLYGON ((-92.31067 32.84022, -92.31052 32.840...     2211122
# 2   POLYGON ((-92.34032 32.70968, -92.33913 32.710...     2211118
# 3   POLYGON ((-92.28528 32.71418, -92.28545 32.714...     2211123
# 4   POLYGON ((-92.29989 32.68925, -92.30001 32.689...     2211120
# 5   POLYGON ((-92.69172 33.01435, -92.69096 33.014...      221114
# 6   POLYGON ((-92.48069 32.93496, -92.48071 32.934...      221118
# 7   POLYGON ((-92.73405 32.80476, -92.73405 32.806...      221115
# 8   POLYGON ((-92.61335 32.82448, -92.61293 32.824...      221116
# 9   POLYGON ((-92.41456 32.75713, -92.41453 32.757...     2211112
# 10  POLYGON ((-92.37147 32.78540, -92.37146 32.785...     2211115
# 11  POLYGON ((-92.41456 32.75713, -92.41447 32.757...     2211114
# 12  POLYGON ((-92.72532 32.83247, -92.72532 32.832...      221112
# 13  POLYGON ((-92.63481 32.85484, -92.63479 32.853...      221113
# 14  POLYGON ((-92.71302 33.01437, -92.71301 33.014...      221111
# 15  POLYGON ((-92.62202 32.93202, -92.62192 32.932...     221114A
# 16  POLYGON ((-92.37514 32.74245, -92.37288 32.740...    2211117A
# 17  POLYGON ((-92.34202 32.70670, -92.34239 32.706...     2211117
# 18  POLYGON ((-92.39726 32.58277, -92.39731 32.582...     2211119
# 19  POLYGON ((-92.51906 32.72043, -92.51895 32.720...     2211116
# 20  POLYGON ((-92.48069 32.93496, -92.48066 32.935...      221119
# 21  POLYGON ((-92.34486 33.01065, -92.34484 33.010...     2211110
# 22  POLYGON ((-92.51233 32.82049, -92.51258 32.820...      221117
# 23  POLYGON ((-92.33069 32.85136, -92.33062 32.851...     2211111
# 24  POLYGON ((-92.40393 32.77336, -92.40393 32.773...     2211113
# 25  POLYGON ((-92.26423 32.81839, -92.26404 32.818...     2211127
# 26  POLYGON ((-92.18954 32.73699, -92.18926 32.737...     2211128
# 27  POLYGON ((-92.24955 32.69994, -92.24945 32.699...     2211129
# 28  POLYGON ((-92.25993 32.90981, -92.25995 32.911...     2211126
# 29  POLYGON ((-92.04562 29.50581, -92.04734 29.506...     2211323
# 30  POLYGON ((-92.25397 29.80451, -92.24874 29.802...     2211316
# 31  POLYGON ((-92.22548 29.94786, -92.22548 29.947...     2211314
# 32  POLYGON ((-92.22543 29.96176, -92.22660 29.961...  2211320B-1
# 33  POLYGON ((-92.24185 29.96243, -92.24242 29.962...  2211320A-2
# 34  POLYGON ((-92.24191 30.00609, -92.24205 30.006...     221138B
# 35  POLYGON ((-92.27497 30.00583, -92.27497 30.005...     2211312
# 36  POLYGON ((-92.24186 30.04212, -92.24227 30.042...     221137B
# 37  POLYGON ((-92.27571 30.02066, -92.27555 30.020...    2211310A
# 38  POLYGON ((-92.54689 29.81532, -92.54863 29.815...      221131
# 39  POLYGON ((-92.30877 29.96350, -92.30876 29.961...      221136
# 40  POLYGON ((-92.41205 30.02200, -92.41219 30.022...     221135A
# 41  POLYGON ((-92.27594 30.04983, -92.27594 30.049...      221139
# 42  POLYGON ((-92.51417 30.04178, -92.51418 30.043...      221132
# 43  POLYGON ((-92.29416 30.00071, -92.29422 30.000...     2211311
# 44  POLYGON ((-92.27599 30.05656, -92.27596 30.053...   221137A-1
# 45  POLYGON ((-92.03116 29.58446, -92.04310 29.590...    2211357B
# 46  POLYGON ((-91.98259 29.91246, -91.98128 29.902...    2211357A
# 47  POLYGON ((-91.98259 29.91246, -91.98314 29.912...     2211353
# 48  POLYGON ((-92.11579 29.91121, -92.11914 29.912...    2211342A
# 49  POLYGON ((-92.03681 29.93992, -92.03739 29.940...    2211345A
#
#                       COUNTYNAMES
# 0       Lincoln Parish, Louisiana
# 1       Lincoln Parish, Louisiana
# 2       Lincoln Parish, Louisiana
# 3       Lincoln Parish, Louisiana
# 4       Lincoln Parish, Louisiana
# 5       Lincoln Parish, Louisiana
# 6       Lincoln Parish, Louisiana
# 7       Lincoln Parish, Louisiana
# 8       Lincoln Parish, Louisiana
# 9       Lincoln Parish, Louisiana
# 10      Lincoln Parish, Louisiana
# 11      Lincoln Parish, Louisiana
# 12      Lincoln Parish, Louisiana
# 13      Lincoln Parish, Louisiana
# 14      Lincoln Parish, Louisiana
# 15      Lincoln Parish, Louisiana
# 16      Lincoln Parish, Louisiana
# 17      Lincoln Parish, Louisiana
# 18      Lincoln Parish, Louisiana
# 19      Lincoln Parish, Louisiana
# 20      Lincoln Parish, Louisiana
# 21      Lincoln Parish, Louisiana
# 22      Lincoln Parish, Louisiana
# 23      Lincoln Parish, Louisiana
# 24      Lincoln Parish, Louisiana
# 25      Lincoln Parish, Louisiana
# 26      Lincoln Parish, Louisiana
# 27      Lincoln Parish, Louisiana
# 28      Lincoln Parish, Louisiana
# 29  St. Charles Parish, Louisiana
# 30  St. Charles Parish, Louisiana
# 31  St. Charles Parish, Louisiana
# 32  St. Charles Parish, Louisiana
# 33  St. Charles Parish, Louisiana
# 34  St. Charles Parish, Louisiana
# 35  St. Charles Parish, Louisiana
# 36  St. Charles Parish, Louisiana
# 37  St. Charles Parish, Louisiana
# 38  St. Charles Parish, Louisiana
# 39  St. Charles Parish, Louisiana
# 40  St. Charles Parish, Louisiana
# 41  St. Charles Parish, Louisiana
# 42  St. Charles Parish, Louisiana
# 43  St. Charles Parish, Louisiana
# 44  St. Charles Parish, Louisiana
# 45  St. Charles Parish, Louisiana
# 46  St. Charles Parish, Louisiana
# 47  St. Charles Parish, Louisiana
# 48  St. Charles Parish, Louisiana
# 49  St. Charles Parish, Louisiana

# %%
precincts.head(50)
# Out:
#       ID        AREA  OBJECTID STATEFP10 COUNTYFP10 VTDST10     GEOID10  \
# 0   3162  147.168381      3360        22        111      24     2211124
# 1   2161  239.121475      3396        22        113      23     2211323
# 2   2148  392.914185      3371        22        113      16     2211316
# 3   2987   29.314260      3352        22        111      22     2211122
# 4   3288  202.215469      3401        22        113      14     2211314
# 5   2544   32.090931      3338        22        111      18     2211118
# 6   2364   34.426968      3347        22        111      23     2211123
# 7   2311    5.970530      3384        22        113   20B-1  2211320B-1
# 8   2100    4.070969      3394        22        113   20A-2  2211320A-2
# 9   3602   30.868038      3357        22        111      20     2211120
# 10  2731    5.513292     14240        22        113      8B     221138B
# 11  2384    1.776306      3376        22        113      12     2211312
# 12  1861    5.218539      2379        22        073      49     2207349
# 13  2648   29.011290      2501        22        079     N27    22079N27
# 14  2448   22.915344      3405        22        113      7B     221137B
# 15  2552    0.900583      3422        22        113     10A    2211310A
# 16  2902   26.980152        24        22        001     1-9    220011-9
# 17   636   27.116941      2363        22        073      54     2207354
# 18  3693   10.885376     18789        22        073     52A    2207352A
# 19  3395    9.278629      2426        22        073      51     2207351
# 20   302   69.651413       621        22        021     6-1    220216-1
# 21  3403   34.771343      1737        22        059     2-1    220592-1
# 22  1364   31.969553      1724        22        059     4-3    220594-3
# 23  1402   40.782768      1725        22        059     8-5    220598-5
# 24  3248   22.274240     10721        22        043     6-4    220436-4
# 25  1716   34.749443      2543        22        079     N17    22079N17
# 26  2885    9.407915      2522        22        079     N22    22079N22
# 27  1976   13.646667      2546        22        079     N26    22079N26
# 28  2264   34.757183      2495        22        079     N28    22079N28
# 29  1779   41.989738      2497        22        079     S16    22079S16
# 30  1207   24.384554      1598        22        055      37     2205537
# 31    50    1.067672        51        22        001    1-4B   220011-4B
# 32   481    0.448875         3        22        001    1-5B   220011-5B
# 33   284    0.490783         6        22        001     1-7    220011-7
# 34  2270    0.897516        36        22        001     1-6    220011-6
# 35  1401    1.338750        38        22        001    1-3A   220011-3A
# 36    63   23.162888        57        22        001     2-2    220012-2
# 37   654   67.045639      2368        22        073      58     2207358
# 38  1760   40.391121      2435        22        073      57     2207357
# 39   737   13.392438      2365        22        073      56     2207356
# 40  3673    5.988739     18788        22        073     56A    2207356A
# 41   305   72.883118       611        22        021     5-1    220215-1
# 42  2612   55.582874       618        22        021     3-1    220213-1
# 43  2456   13.059750      1723        22        059     3-1    220593-1
# 44   695   20.205505      1719        22        059     3-2    220593-2
# 45  2490   47.859116      1740        22        059     8-2    220598-2
# 46  1784   47.616730      1739        22        059     8-3    220598-3
# 47  2855   55.516575     10713        22        043     8-4    220438-4
# 48  2624   20.417221      1101        22        043     6-1    220436-1
# 49  3128   43.532471      2536        22        079     S19    22079S19
#
#    VTDI10          NAME10      NAMELSAD10  ...   MCD PLACE    VTD  TRACT  \
# 0       A     Precinct 24     Precinct 24  ...  None  None     24   None
# 1       A     Precinct 23     Precinct 23  ...  None  None     23   None
# 2       A     Precinct 16     Precinct 16  ...  None  None     16   None
# 3       A     Precinct 22     Precinct 22  ...  None  None     22   None
# 4       A     Precinct 14     Precinct 14  ...  None  None     14   None
# 5       A     Precinct 18     Precinct 18  ...  None  None     18   None
# 6       A     Precinct 23     Precinct 23  ...  None  None     23   None
# 7       A  Precinct 20B-1  Precinct 20B-1  ...  None  None  20B-1   None
# 8       A  Precinct 20A-2  Precinct 20A-2  ...  None  None  20A-2   None
# 9       A     Precinct 20     Precinct 20  ...  None  None     20   None
# 10   None     Precinct 8B     Precinct 8B  ...  None  None     8B   None
# 11      A     Precinct 12     Precinct 12  ...  None  None     12   None
# 12      A     Precinct 49     Precinct 49  ...  None  None     49   None
# 13      A    Precinct N27    Precinct N27  ...  None  None    N27   None
# 14      A     Precinct 7B     Precinct 7B  ...  None  None     7B   None
# 15      A    Precinct 10A    Precinct 10A  ...  None  None    10A   None
# 16      A    Precinct 1-9    Precinct 1-9  ...  None  None    1-9   None
# 17      A     Precinct 54     Precinct 54  ...  None  None     54   None
# 18   None    Precinct 52A    Precinct 52A  ...  None  None    52A   None
# 19      A     Precinct 51     Precinct 51  ...  None  None     51   None
# 20      A    Precinct 6-1    Precinct 6-1  ...  None  None    6-1   None
# 21      A    Precinct 2-1    Precinct 2-1  ...  None  None    2-1   None
# 22      A    Precinct 4-3    Precinct 4-3  ...  None  None    4-3   None
# 23      A    Precinct 8-5    Precinct 8-5  ...  None  None    8-5   None
# 24   None    Precinct 6-4    Precinct 6-4  ...  None  None    6-4   None
# 25      A    Precinct N17    Precinct N17  ...  None  None    N17   None
# 26      A    Precinct N22    Precinct N22  ...  None  None    N22   None
# 27      A    Precinct N26    Precinct N26  ...  None  None    N26   None
# 28      A    Precinct N28    Precinct N28  ...  None  None    N28   None
# 29      A    Precinct S16    Precinct S16  ...  None  None    S16   None
# 30      A     Precinct 37     Precinct 37  ...  None  None     37   None
# 31      A   Precinct 1-4B   Precinct 1-4B  ...  None  None   1-4B   None
# 32      A   Precinct 1-5B   Precinct 1-5B  ...  None  None   1-5B   None
# 33      A    Precinct 1-7    Precinct 1-7  ...  None  None    1-7   None
# 34      A    Precinct 1-6    Precinct 1-6  ...  None  None    1-6   None
# 35      A   Precinct 1-3A   Precinct 1-3A  ...  None  None   1-3A   None
# 36      A    Precinct 2-2    Precinct 2-2  ...  None  None    2-2   None
# 37      A     Precinct 58     Precinct 58  ...  None  None     58   None
# 38      A     Precinct 57     Precinct 57  ...  None  None     57   None
# 39      A     Precinct 56     Precinct 56  ...  None  None     56   None
# 40   None    Precinct 56A    Precinct 56A  ...  None  None    56A   None
# 41      A    Precinct 5-1    Precinct 5-1  ...  None  None    5-1   None
# 42      A    Precinct 3-1    Precinct 3-1  ...  None  None    3-1   None
# 43      A    Precinct 3-1    Precinct 3-1  ...  None  None    3-1   None
# 44      A    Precinct 3-2    Precinct 3-2  ...  None  None    3-2   None
# 45      A    Precinct 8-2    Precinct 8-2  ...  None  None    8-2   None
# 46      A    Precinct 8-3    Precinct 8-3  ...  None  None    8-3   None
# 47   None    Precinct 8-4    Precinct 8-4  ...  None  None    8-4   None
# 48      A    Precinct 6-1    Precinct 6-1  ...  None  None    6-1   None
# 49      A    Precinct S19    Precinct S19  ...  None  None    S19   None
#
#     BGROUP BLOCK TOT_POP  SHAPE_AREA SHAPE_LEN  \
# 0     None  None     961    0.036730  1.254069
# 1     None  None    1175    0.057650  2.019706
# 2     None  None     166    0.094700  1.493221
# 3     None  None    1090    0.007300  0.574391
# 4     None  None    2403    0.048840  1.063200
# 5     None  None     963    0.007980  0.605118
# 6     None  None     895    0.008580  0.451130
# 7     None  None     663    0.001440  0.230453
# 8     None  None     369    0.000990  0.178493
# 9     None  None     587    0.007680  0.590152
# 10    None  None     542    0.001330  0.205851
# 11    None  None    1272    0.000430  0.104613
# 12    None  None     871    0.001300  0.203125
# 13    None  None    2095    0.007110  0.357346
# 14    None  None    1192    0.005550  0.465208
# 15    None  None    1092    0.000220  0.067344
# 16    None  None    1508    0.006540  0.635376
# 17    None  None    2216    0.006730  0.496420
# 18    None  None    1021    0.002704  0.213485
# 19    None  None    2097    0.002310  0.211343
# 20    None  None     490    0.017200  0.710044
# 21    None  None    1385    0.008580  0.610742
# 22    None  None     213    0.007880  0.594062
# 23    None  None     145    0.010030  0.584488
# 24    None  None     277    0.005470  0.516947
# 25    None  None    1063    0.008530  0.562693
# 26    None  None     907    0.002310  0.248873
# 27    None  None    2755    0.003350  0.286107
# 28    None  None    1160    0.008510  0.498656
# 29    None  None    1370    0.010280  0.512179
# 30    None  None    2547    0.005910  0.439527
# 31    None  None     958    0.000260  0.069503
# 32    None  None     694    0.000110  0.044149
# 33    None  None    1005    0.000120  0.088877
# 34    None  None     819    0.000220  0.069096
# 35    None  None     977    0.000320  0.106598
# 36    None  None    1151    0.005620  0.453734
# 37    None  None    1407    0.016620  0.710487
# 38    None  None    2815    0.010020  0.622682
# 39    None  None    2114    0.003324  0.312013
# 40    None  None    1440    0.001487  0.203357
# 41    None  None     472    0.018050  0.798053
# 42    None  None     267    0.013750  0.680941
# 43    None  None    1386    0.003220  0.323891
# 44    None  None     517    0.004980  0.526386
# 45    None  None     288    0.011790  0.777738
# 46    None  None     317    0.011720  0.715263
# 47    None  None    1165    0.013650  1.096230
# 48    None  None     982    0.005020  0.520621
# 49    None  None     434    0.010650  0.619270
#
#                                              geometry
# 0   POLYGON ((-92.34486 33.01065, -92.34482 33.010...
# 1   POLYGON ((-92.04562 29.50581, -92.04734 29.506...
# 2   POLYGON ((-92.25397 29.80451, -92.24874 29.802...
# 3   POLYGON ((-92.31067 32.84022, -92.31052 32.840...
# 4   POLYGON ((-92.22548 29.94786, -92.22548 29.947...
# 5   POLYGON ((-92.34032 32.70968, -92.33913 32.710...
# 6   POLYGON ((-92.28528 32.71418, -92.28545 32.714...
# 7   POLYGON ((-92.22543 29.96176, -92.22660 29.961...
# 8   POLYGON ((-92.24185 29.96243, -92.24242 29.962...
# 9   POLYGON ((-92.29989 32.68925, -92.30001 32.689...
# 10  POLYGON ((-92.24191 30.00609, -92.24205 30.006...
# 11  POLYGON ((-92.27497 30.00583, -92.27497 30.005...
# 12  POLYGON ((-92.31287 32.58280, -92.31264 32.582...
# 13  POLYGON ((-92.23323 31.31882, -92.23318 31.311...
# 14  POLYGON ((-92.24186 30.04212, -92.24227 30.042...
# 15  POLYGON ((-92.27571 30.02066, -92.27555 30.020...
# 16  POLYGON ((-92.28467 30.14744, -92.28512 30.147...
# 17  POLYGON ((-92.35912 32.50569, -92.35890 32.505...
# 18  POLYGON ((-92.26081 32.49327, -92.26151 32.492...
# 19  POLYGON ((-92.29903 32.57525, -92.29863 32.574...
# 20  POLYGON ((-92.19627 31.92778, -92.19748 31.927...
# 21  POLYGON ((-92.31262 31.92738, -92.31214 31.927...
# 22  POLYGON ((-92.25510 31.81409, -92.25491 31.814...
# 23  POLYGON ((-92.18692 31.60714, -92.18693 31.607...
# 24  POLYGON ((-92.27495 31.49483, -92.27484 31.494...
# 25  POLYGON ((-92.36811 31.44558, -92.36787 31.445...
# 26  POLYGON ((-92.33914 31.38339, -92.33891 31.383...
# 27  POLYGON ((-92.24141 31.32216, -92.24147 31.322...
# 28  POLYGON ((-92.32598 31.28567, -92.32589 31.285...
# 29  POLYGON ((-92.34797 31.21060, -92.34692 31.210...
# 30  POLYGON ((-92.17554 30.13281, -92.18407 30.135...
# 31  POLYGON ((-92.26911 30.21506, -92.27035 30.215...
# 32  POLYGON ((-92.28632 30.22716, -92.28632 30.227...
# 33  POLYGON ((-92.27528 30.25243, -92.27551 30.252...
# 34  POLYGON ((-92.28106 30.24202, -92.28141 30.242...
# 35  POLYGON ((-92.27407 30.25554, -92.27420 30.255...
# 36  POLYGON ((-92.27905 30.25978, -92.27933 30.259...
# 37  POLYGON ((-92.32231 32.32958, -92.32201 32.329...
# 38  POLYGON ((-92.12122 32.36047, -92.12135 32.360...
# 39  POLYGON ((-92.29796 32.40816, -92.29796 32.408...
# 40  POLYGON ((-92.28115 32.43738, -92.28116 32.437...
# 41  POLYGON ((-92.31185 32.27744, -92.30138 32.277...
# 42  POLYGON ((-92.18657 32.08023, -92.18711 32.080...
# 43  POLYGON ((-92.31261 31.92019, -92.31211 31.920...
# 44  POLYGON ((-92.27881 31.84199, -92.27849 31.842...
# 45  POLYGON ((-92.27966 31.77883, -92.27954 31.778...
# 46  POLYGON ((-92.21115 31.60562, -92.21129 31.605...
# 47  POLYGON ((-92.30500 31.58715, -92.30500 31.587...
# 48  POLYGON ((-92.27593 31.49448, -92.27633 31.494...
# 49  POLYGON ((-92.34431 31.12037, -92.34383 31.120...
#
# [50 rows x 32 columns]
